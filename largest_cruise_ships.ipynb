# %%
import pandas as pd

# %% [markdown]
# Wikipedia provides two categories of the largest cruise ships to explore. A table of data is provided for both active cruise ships as well as cruise ships that are on order (or under construction). Start by taking a brief look at both tables as obtained from the "largest_cruise_ships.py" script.

# %%
df = pd.read_csv('largest_cruise_ships.csv')
df.head()
# Out:
#    Rank[a]             Ship name                 Cruise line[b]      Year[c]  \
# 0  Rank[a]             Ship name                 Cruise line[b]      Year[c]
# 1        1  Symphony of the Seas  Royal Caribbean International   2018[k][7]
# 2        2   Harmony of the Seas  Royal Caribbean International  2016[k][29]
# 3        3     Oasis of the Seas  Royal Caribbean International  2009[k][31]
# 4        4    Allure of the Seas  Royal Caribbean International     2010[33]
#
#    Grosstonnage[d]        Lengthoverall[d][e]               Beam[d]  \
# 0  Grosstonnage[d]        Lengthoverall[d][e]            Maximum[g]
# 1       228,081[7]  361.011 m(1,184.42 ft)[7]   65.7 m(215.5 ft)[6]
# 2      226,963[29]   362.12 m(1,188.1 ft)[29]  65.7 m(215.5 ft)[30]
# 3      226,838[31]        360 m(1,180 ft)[31]    60.5 m(198 ft)[31]
# 4      225,282[33]        360 m(1,180 ft)[33]    60.5 m(198 ft)[33]
#
#                Beam[d].1  Staterooms Passenger capacity[f]  \
# ...

# %%
df2 = pd.read_csv('largest_on_order_ships.csv')
df2.head()
# Out:
#    Rank[a]  Ship, class, or project name[b]                 Cruise line[c]  \
# 0  Rank[a]  Ship, class, or project name[b]                 Cruise line[c]
# 1        1                      Oasis Class  Royal Caribbean International
# 2        2          Wonder of the Seas[150]  Royal Caribbean International
# 3        3                Global Dream[142]                  Dream Cruises
# 4        3                     Global Class                  Dream Cruises
#
#    Year(planned)[d]  Grosstonnage[b]       Lengthoverall[b]  \
# 0  Year(planned)[d]  Grosstonnage[b]       Lengthoverall[b]
# 1     2024[19][149]      231,000[19]    362 m(1,188 ft)[19]
# 2         2022[150]    >228,081[137]  >362 m(1,188 ft)[137]
# 3         2021[142]     208,000[142]   342 m(1,122 ft)[142]
# 4         2022[142]     208,000[142]   342 m(1,122 ft)[142]
#
#                   Beam[b]               Beam[b].1  Staterooms[b]  \
# 0              Maximum[f]            Waterline[g]  Staterooms[b]
# ...

# %% [markdown]
# A quick scan of the structure of the tables shows that this data will require cleaning before putting it to use. The header row is split into two rows due to a couple columns that are split into two categories. This resulted in all the columns receiving two header rows, even when one of the rows is a duplicate header that provides no extra info. Footnotes also exist throughout the table which will need to be removed.
